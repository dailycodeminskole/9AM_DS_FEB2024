# %%
import numpy as np
import pandas as pd

# %%
# https://pandas.pydata.org/docs/user_guide/reshaping.html#pivot

# %%
df = pd.read_csv('Sales_Funnel_CRM.csv')

# %%
df
# Out:
#     Account Number       Company       Contact Account Manager  \
# 0          2123398        Google   Larry Pager    Edward Thorp
# 1          2123398        Google   Larry Pager    Edward Thorp
# 2          2123398        Google   Larry Pager    Edward Thorp
# 3          2192650          BOBO   Larry Pager    Edward Thorp
# 4           420496          IKEA     Elon Tusk    Edward Thorp
# 5           636685    Tesla Inc.     Elon Tusk    Edward Thorp
# 6           636685    Tesla Inc.     Elon Tusk    Edward Thorp
# 7          1216870     Microsoft   Will Grates    Edward Thorp
# 8          2200450       Walmart   Will Grates    Edward Thorp
# 9           405886         Apple  Cindy Phoner  Claude Shannon
# 10          470248  Exxon Mobile  Cindy Phoner  Claude Shannon
# 11          698032           ATT  Cindy Phoner  Claude Shannon
# 12          698032           ATT  Cindy Phoner  Claude Shannon
# 13          902797    CVS Health  Emma Gordian  Claude Shannon
# ...

# %%
df.shape
# Out:
# (17, 8)

# %%
# df.pivot " pivoting "
# df.pivot_table " aggr func"

# %%
# help(pd.pivot)

# %%
#extracting the required dataframes

# %%
Licenses = df[['Company','Product','Licenses']]

# %%
Licenses
# Out:
#          Company          Product  Licenses
# 0         Google        Analytics       150
# 1         Google       Prediction       150
# 2         Google         Tracking       300
# 3           BOBO        Analytics       150
# 4           IKEA        Analytics       300
# 5     Tesla Inc.        Analytics       300
# 6     Tesla Inc.       Prediction       150
# 7      Microsoft         Tracking       300
# 8        Walmart        Analytics       150
# 9          Apple        Analytics       300
# 10  Exxon Mobile        Analytics       150
# 11           ATT         Tracking       150
# 12           ATT       Prediction       150
# 13    CVS Health         Tracking       450
# 14    Salesforce        Analytics       750
# 15         Cisco        Analytics       300
# 16         Cisco  GPS Positioning       300

# %%
pd.pivot(data=Licenses,index='Company',columns='Product',values='Licenses')
# Out:
# Product       Analytics  GPS Positioning  Prediction  Tracking
# Company
#  Google           150.0              NaN       150.0     300.0
# ATT                 NaN              NaN       150.0     150.0
# Apple             300.0              NaN         NaN       NaN
# BOBO              150.0              NaN         NaN       NaN
# CVS Health          NaN              NaN         NaN     450.0
# Cisco             300.0            300.0         NaN       NaN
# Exxon Mobile      150.0              NaN         NaN       NaN
# IKEA              300.0              NaN         NaN       NaN
# Microsoft           NaN              NaN         NaN     300.0
# Salesforce        750.0              NaN         NaN       NaN
# Tesla Inc.        300.0              NaN       150.0       NaN
# Walmart           150.0              NaN         NaN       NaN

# %% [markdown]
# # using pivot table

# %%
pd.pivot_table(data=Licenses,index='Company')
# Out:
# C:\Users\RAHUL\AppData\Local\Temp\ipykernel_16824\3735144073.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pd.pivot_table(data=Licenses,index='Company')
#               Licenses
# Company
#  Google            200
# ATT                150
# Apple              300
# BOBO               150
# CVS Health         450
# Cisco              300
# Exxon Mobile       150
# IKEA               300
# Microsoft          300
# Salesforce         750
# Tesla Inc.         225
# Walmart            150

# %%
pd.pivot_table(data=df,index='Company')
# Out:
# C:\Users\RAHUL\AppData\Local\Temp\ipykernel_16824\2359150906.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pd.pivot_table(data=df,index='Company')
#               Account Number  Licenses  Sale Price
# Company
#  Google              2123398       200     1050000
# ATT                   698032       150      525000
# Apple                 405886       300     4550000
# BOBO                 2192650       150     2450000
# CVS Health            902797       450      490000
# Cisco                2169499       300     2450000
# Exxon Mobile          470248       150     2100000
# IKEA                  420496       300     4550000
# Microsoft            1216870       300      350000
# Salesforce           2046943       750     7000000
# Tesla Inc.            636685       225     1750000
# ...

# %%
pd.pivot_table(data=Licenses,index='Company',aggfunc='sum')
# Out:
# C:\Users\RAHUL\AppData\Local\Temp\ipykernel_16824\3935822755.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pd.pivot_table(data=Licenses,index='Company',aggfunc='sum')
#               Licenses
# Company
#  Google            600
# ATT                300
# Apple              300
# BOBO               150
# CVS Health         450
# Cisco              600
# Exxon Mobile       150
# IKEA               300
# Microsoft          300
# Salesforce         750
# Tesla Inc.         450
# Walmart            150

# %%
# groupby

# %%
df.groupby('Company').sum()
# Out:
# C:\Users\RAHUL\AppData\Local\Temp\ipykernel_16824\2836748086.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Company').sum()
#               Account Number  Licenses  Sale Price
# Company
#  Google              6370194       600     3150000
# ATT                  1396064       300     1050000
# Apple                 405886       300     4550000
# BOBO                 2192650       150     2450000
# CVS Health            902797       450      490000
# Cisco                4338998       600     4900000
# Exxon Mobile          470248       150     2100000
# IKEA                  420496       300     4550000
# Microsoft            1216870       300      350000
# Salesforce           2046943       750     7000000
# Tesla Inc.           1273370       450     3500000
# ...

# %%
pd.pivot_table(data=df,index='Company',aggfunc='sum')
# Out:
# C:\Users\RAHUL\AppData\Local\Temp\ipykernel_16824\1966234139.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pd.pivot_table(data=df,index='Company',aggfunc='sum')
#               Account Number  Licenses  Sale Price
# Company
#  Google              6370194       600     3150000
# ATT                  1396064       300     1050000
# Apple                 405886       300     4550000
# BOBO                 2192650       150     2450000
# CVS Health            902797       450      490000
# Cisco                4338998       600     4900000
# Exxon Mobile          470248       150     2100000
# IKEA                  420496       300     4550000
# Microsoft            1216870       300      350000
# Salesforce           2046943       750     7000000
# ...

# %%
pd.pivot_table(data=df,index='Company',values=['Licenses','Sale Price'], aggfunc='sum')
# Out:
#               Licenses  Sale Price
# Company
#  Google            600     3150000
# ATT                300     1050000
# Apple              300     4550000
# BOBO               150     2450000
# CVS Health         450      490000
# Cisco              600     4900000
# Exxon Mobile       150     2100000
# IKEA               300     4550000
# Microsoft          300      350000
# Salesforce         750     7000000
# Tesla Inc.         450     3500000
# Walmart            150     2450000

# %%
# replacing Nan with zero

# %%
# rearranging the index and columns for more readability
