# %%
# https://matplotlib.org

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# basics of plotting revised
'''
name(x,y)
p(3,7)
a(1,1)

x = [all values for x coordinates]
y = [all values for y coordinates]


'''
# Out:
# '\nname(x,y)\np(3,7)\na(1,1)\n\nx = [all values for x coordinates]\ny = [all values for y coordinates]\n\n\n'

# %%
# x = [0,1,2]
y = [3,5,9]

plt.plot(y) #default x = [0,1,2,3,...] will be used for every value of y

# %%
x = [0,1,2]
y = [3,5,9]

plt.plot(x,y)# if only one parameter is there ,  it will be considered as y-axis , f(x) = y

# %%
x = [0,1,2]
y = [3,5,9]

plt.plot(x)# if only one parameter is there ,  it will be considered as y-axis , f(x) = y

# %%
a = [0,1,2]
b = [3,5,9]

plt.plot(b)

# %%
x = [0,1,2]
y = [3,5,9]

plt.plot(x,y)
plt.show()# for other code editors

# %% [markdown]
# # Saving a figure

# %%
x = [0,1,2]
y = [3,5,9]

plt.plot(x,y)
plt.savefig("First_plot.jpg")

# %% [markdown]
# # Some complex plots

# %%
x_val = [-3,-2,-1,0,1,2,3]
y_val = [9,4,1,0,1,4,9]
plt.plot(x_val,y_val)
plt.show()

# %%
# using numpy

x_val = np.array([-3,-2,-1,0,1,2,3]) #elementwise operation possible
y_val = x_val**2
plt.plot(x_val,y_val)
plt.show()

# %%
x_val = np.arange(-4,4,.1) #elementwise operation possible
y_val = x_val**2
plt.plot(x_val,y_val)
plt.show()

# %%
x_val = np.arange(-4,4,.1) #elementwise operation possible
y_val = x_val**2
plt.xticks(np.arange(-4,4,.3),rotation=90)
plt.plot(x_val,y_val)
plt.show()
